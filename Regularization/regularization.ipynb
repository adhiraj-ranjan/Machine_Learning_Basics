# %% [markdown]
# ## Regularization Techniques
# ### -> Lasso Regularization
# ### -> Ridge Regularization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("../sample_data/california_housing_train.csv")
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-66b1d5ff531a> in <cell line: 1>()
# ----> 1 dataset = pd.read_csv("../sample_data/california_housing_train.csv")
#       2 dataset.head()
#
# ...

# %%
dataset.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925208           -0.114250     0.047010
# latitude            -0.925208  1.000000            0.016454    -0.038773
# housing_median_age  -0.114250  0.016454            1.000000    -0.360984
# total_rooms          0.047010 -0.038773           -0.360984     1.000000
# total_bedrooms       0.071802 -0.069373           -0.320434     0.928403
# population           0.101674 -0.111261           -0.295890     0.860170
# households           0.059628 -0.074902           -0.302754     0.919018
# median_income       -0.015485 -0.080303           -0.115932     0.195383
# median_house_value  -0.044982 -0.144917            0.106758     0.130991
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071802    0.101674    0.059628      -0.015485
# latitude                 -0.069373   -0.111261   -0.074902      -0.080303
# ...

# %%
sns.heatmap(dataset.corr(), annot=True)
plt.show()

# %%
# !zip -r sample.zip sample_data/
# Out:
#   adding: sample_data/ (stored 0%)
#   adding: sample_data/README.md (deflated 42%)
#   adding: sample_data/anscombe.json (deflated 83%)
#   adding: sample_data/.ipynb_checkpoints/ (stored 0%)
#   adding: sample_data/california_housing_test.csv (deflated 76%)
#   adding: sample_data/california_housing_train.csv (deflated 79%)
#   adding: sample_data/mnist_test.csv (deflated 88%)
#   adding: sample_data/mnist_train_small.csv (deflated 88%)

# %% [markdown]
# ![(25) Data Science FULL Course for Beginners in 27 HOURS - 2024 Edition (10).jpeg](data:image/jpeg;base64,...)![(25) Data Science FULL Course for Beginners in 27 HOURS - 2024 Edition (11).jpeg](data:image/jpeg;base64,...)![(25) Data Science FULL Course for Beginners in 27 HOURS - 2024 Edition (12).jpeg](data:image/jpeg;base64,...)![(25) Data Science FULL Course for Beginners in 27 HOURS - 2024 Edition (13).jpeg](data:image/jpeg;base64,...)![(25) Data Science FULL Course for Beginners in 27 HOURS - 2024 Edition (14).jpeg](data:image/jpeg;base64,...)![(25) Data Science FULL Course for Beginners in 27 HOURS - 2024 Edition (15).jpeg](data:image/jpeg;base64,...)
